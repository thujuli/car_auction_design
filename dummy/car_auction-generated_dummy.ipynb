# %%
# Instalasi library Faker
# !pip install Faker
# !pip install tabulate
# Out:
# Requirement already satisfied: Faker in /home/thujuli/anaconda3/lib/python3.9/site-packages (18.4.0)
# Requirement already satisfied: python-dateutil>=2.4 in /home/thujuli/anaconda3/lib/python3.9/site-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/thujuli/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Requirement already satisfied: tabulate in /home/thujuli/anaconda3/lib/python3.9/site-packages (0.8.10)

# %%
# Import Library yang akan digunakan
from faker import Faker
from tabulate import tabulate
import random
from datetime import datetime, timedelta
import csv

# %%
# Definisikan bahwa data yang digunakan menggunakan format Indonesia
FAKER = Faker('id_ID')

# %% [markdown]
# ## Membuat dummy data
# ### Dummy data yang sudah tersedia untuk tabel-tabel berikut:
# * cities
# * products
#
# ### Dummy data yang dibuat adalah tabel-tabel berikut:
#
# * sellers
# * customers
# * ads
# * bids

# %%
def show_data(table):
    """
    Fungsi untuk menampilkan data

    arg:
        - table (dict) : data dictionary yang ingin ditampilkan

    return:
        None
    """

    tab = tabulate(tabular_data = table,
                   headers = table.keys(),
                   tablefmt = "psql",
                   numalign = "center")
    print(tab)

# %%
def generate_name(n_name):
    """
    Fungsi untuk membuat nama dummy

    arg:
        - n_name (int) : jumlah data nama yang ingin dibuat

    return:
        names (list) : list nama yang sudah dibuat
    """

    names = list()

    while len(names) < n_name:

        first_name = FAKER.first_name()
        last_name = FAKER.last_name()

        full_name = (f'{first_name} {last_name}')
        if full_name not in names:
            names.append(full_name)

    return names

# %%
def csv_to_dict(filename):
    """
    Fungsi untuk ekstrak file csv menjadi list of dictionary

    arg:
        - filename (str) : nama file csv yang akan dibuka
    return:
        - data  (list) :  list of dictionary
    """

    # buka file csv
    with open(f'{filename}', mode='r', encoding='utf-8-sig') as file:
        csv_reader = csv.DictReader(file)

        # simpan dalam bentuk list of dictionary
        data = {}
        for row in csv_reader:
            for key, value in row.items():
                # setdefault() untuk menambahkan key ke result_dict
                # value dari key diisi dengan empty list dulu
                # empty list diisi dengan method append per baris data
                data.setdefault(key, []).append(value)

    return data

# %% [markdown]
# ### Dummy data tabel sellers
# * Deskripsi: Menyimpan informasi tentang data diri seller
# * Relasi: Tabel cities(Parent Table)

# %%
# Ekstrak file city.csv menjadi list of dictionary
city_table = csv_to_dict('city.csv')

# %%
# Lihat data cities
show_data(city_table)
# Out:
# +-----------+----------------------+------------+-------------+
# |  kota_id  | nama_kota            |  latitude  |  longitude  |
# |-----------+----------------------+------------+-------------|
# |   3171    | Kota Jakarta Pusat   |  -6.18649  |   106.834   |
# |   3172    | Kota Jakarta Utara   |  -6.12143  |   106.774   |
# |   3173    | Kota Jakarta Barat   |  -6.1352   |   106.813   |
# |   3174    | Kota Jakarta Selatan |  -6.30064  |   106.814   |
# |   3175    | Kota Jakarta Timur   |  -6.26445  |   106.896   |
# |   3573    | Kota Malang          |  -7.98189  |   112.627   |
# |   3578    | Kota Surabaya        |  -7.28917  |   112.734   |
# |   3471    | Kota Yogyakarta      |  -7.79722  |   110.369   |
# |   3273    | Kota Bandung         |  -6.91474  |   107.61    |
# |   1371    | Kota Padang          |   -0.95    |   100.353   |
# |   1375    | Kota Bukittinggi     | -0.305556  |   100.369   |
# |   6471    | Kota Balikpapan      |  -1.26354  |   116.828   |
# |   6472    | Kota Samarinda       | -0.502183  |   117.154   |
# |   7371    | Kota Makassar        |  -5.13333  |   119.417   |
# |   5171    | Kota Denpasar        |  -8.65629  |   115.222   |
# +-----------+----------------------+------------+-------------+

# %%
def seller_table(n_data, city_table, is_print):
    """
    Fungsi untuk membuat dummy data seller table
    header:
        - seller_id
        - city_id
        - first_name
        - last_name
        - phone
    arg:
        - n_data (int)  : Jumlah seller yang ingin dibuat
        - city_table (list)  : list of dictionary data city
        - is_print  (bool) : Jika True akan menampilkan hasil data

    return:
        - table  (list) :  
    """

    # Buat table
    table = {}
    table["seller_id"] = [i+1 for i in range(n_data)]
    table["city_id"] = [random.choice(city_table['kota_id']) for i in range(n_data)]
    names = generate_name(n_data)
    table["first_name"] = [i.split(' ')[0] for i in names] 
    table["last_name"] = [i.split(' ')[1] for i in names] 
    table["phone"] = [FAKER.phone_number() for i in range(n_data)]

    # Print table
    if is_print:
        show_data(table)

    return table

# %%
seller_table = seller_table(n_data=100, city_table=city_table, is_print=True)
# Out:
# +-------------+-----------+--------------+-------------+---------------------+
# |  seller_id  |  city_id  | first_name   | last_name   | phone               |
# |-------------+-----------+--------------+-------------+---------------------|
# |      1      |   1375    | Eka          | Usamah      | +62 (0177) 356 4840 |
# |      2      |   1375    | Paiman       | Latupono    | +62 (0684) 992 4835 |
# |      3      |   6472    | Teddy        | Rahayu      | +62 (090) 493-4201  |
# |      4      |   7371    | Hartana      | Napitupulu  | +62-084-880-0835    |
# |      5      |   3173    | Iriana       | Hutagalung  | +62 (064) 145 0722  |
# |      6      |   3175    | Anita        | Dongoran    | +62 (068) 239-6850  |
# |      7      |   3173    | Ghani        | Sudiati     | +62 (0836) 344 3889 |
# |      8      |   3171    | Maryadi      | Usada       | (004) 521-3831      |
# |      9      |   3573    | Unggul       | Laksmiwati  | 081 279 5591        |
# |     10      |   5171    | Bella        | Haryanti    | +62 (71) 346-8301   |
# |     11      |   7371    | Bakianto     | Budiman     | (0958) 738-5100     |
# |     12      |   3471    | Bakda        | Hutapea     | +62-639-780-0265    |
# |     13      |   5171    | Bakianto     | Gunarto     | +62 (85) 378-8083   |
# |     14      |   3172    | Olivia       | Widodo      | +62 (903) 925-0649  |
# |     15      |   1371    | Panji        | Mandasari   | +62 (011) 273 1802  |
# |     16      |   3171    | Imam         | Laksmiwati  | 0889063828          |
# |     17      |   3573    | Sari         | Palastri    | +62 (0196) 504 3285 |
# |     18      |   3573    | Caturangga   | Simanjuntak | 085 943 1989        |
# |     19      |   6472    | Putri        | Santoso     | (027) 745-3662      |
# |     20      |   7371    | Ibun         | Prakasa     | (011) 417-6346      |
# |     21      |   6471    | Saiful       | Ramadan     | +62 (001) 687 1356  |
# |     22      |   3174    | Ajimin       | Nugroho     | +62-069-226-8162    |
# |     23      |   5171    | Hasta        | Siregar     | +62-88-395-4047     |
# |     66      |   6472    | Ratna        | Lazuardi    | 0805601460          |
# |     67      |   3273    | Jaya         | Natsir      | +62 (075) 459 6619  |
# |     68      |   3171    | Nalar        | Nainggolan  | 084 032 7695        |
# |     69      |   3173    | Yulia        | Siregar     | +62-60-881-3331     |
# |     70      |   7371    | Usman        | Anggraini   | 0855834170          |
# |     71      |   6471    | Jasmin       | Haryanto    | +62-039-941-8100    |
# |     72      |   5171    | Putri        | Nasyiah     | +62 (906) 801 3454  |
# |     73      |   3174    | Indra        | Nurdiyanti  | (0633) 562 6147     |
# |     74      |   6472    | Ifa          | Wasita      | +62-181-637-8989    |
# |     75      |   3273    | Panji        | Hidayanto   | +62 (836) 458 6775  |
# |     76      |   5171    | Tasnim       | Hutapea     | +62 (177) 559 2446  |
# |     77      |   6472    | Gantar       | Hutasoit    | +62-37-406-1978     |
# |     78      |   5171    | Gangsar      | Oktaviani   | +62 (0258) 826 9733 |
# |     79      |   3578    | Harsanto     | Nasyidah    | +62 (088) 872-0589  |
# |     80      |   3174    | Cemplunk     | Haryanti    | +62-03-109-1582     |
# |     81      |   5171    | Wisnu        | Rajata      | +62 (036) 524-9742  |
# |     82      |   1375    | Zamira       | Prakasa     | +62-636-693-0512    |
# |     83      |   1371    | Irwan        | Aryani      | +62 (0717) 433 7234 |
# |     84      |   3173    | Putri        | Simanjuntak | (011) 774-2197      |
# |     85      |   7371    | Paulin       | Wijayanti   | +62-63-563-0471     |
# |     86      |   5171    | Lamar        | Prabowo     | +62 (021) 762 1240  |
# |     87      |   1371    | Gilda        | Pudjiastuti | +62 (38) 045 5593   |
# |     88      |   3175    | Bambang      | Permata     | +62 (403) 943 0101  |
# |     89      |   3273    | Purwanto     | Marbun      | +62 (075) 435-8856  |
# |     90      |   3175    | Kacung       | Maryati     | (001) 490 5795      |
# |     91      |   3172    | Oliva        | Purwanti    | (003) 399 2546      |
# |     92      |   3273    | Eka          | Budiman     | (0177) 574-7083     |
# |     93      |   1375    | Azalea       | Usamah      | +62 (394) 972 8925  |
# |     94      |   3573    | Wirda        | Tampubolon  | +62-0309-286-9224   |
# |     95      |   3578    | Maria        | Zulkarnain  | +62 (54) 792 3655   |
# |     96      |   3578    | Joko         | Hardiansyah | (0180) 658 9091     |
# |     97      |   5171    | Kamidin      | Ardianto    | +62 (0521) 657 2432 |
# |     98      |   6471    | Bala         | Simanjuntak | 0888397350          |
# |     99      |   3471    | Marsito      | Hassanah    | 082 928 1039        |
# |     100     |   6471    | Febi         | Widodo      | (041) 990 2594      |
# +-------------+-----------+--------------+-------------+---------------------+

# %% [markdown]
# ### Dummy data tabel customers
# * Deskripsi: Menyimpan informasi tentang data diri customer
# * Relasi: Tabel cities(Parent Table)

# %%
def customer_table(n_data, city_table, is_print):
    """
    Fungsi untuk membuat dummy data customer table
    header:
        - customer_id
        - city_id
        - first_name
        - last_name
        - phone
    arg:
        - n_data (int)  : Jumlah data yang ingin dibuat
        - city_table (list)  : list of dictionary data city
        - is_print  (bool) : Jika True akan menampilkan hasil data

    return:
        - table  (list) :  
    """

    # Buat table
    table = {}
    table["customer_id"] = [i+1 for i in range(n_data)]
    table["city_id"] = [random.choice(city_table['kota_id']) for i in range(n_data)]
    names = generate_name(n_data)
    table["first_name"] = [i.split(' ')[0] for i in names] 
    table["last_name"] = [i.split(' ')[1] for i in names] 
    table["phone"] = [FAKER.phone_number() for i in range(n_data)]

    # Print table
    if is_print:
        show_data(table)

    return table

# %%
customer_table = customer_table(n_data=100, city_table=city_table, is_print=True)
# Out:
# +---------------+-----------+--------------+-------------+---------------------+
# |  customer_id  |  city_id  | first_name   | last_name   | phone               |
# |---------------+-----------+--------------+-------------+---------------------|
# |       1       |   6472    | Kalim        | Andriani    | +62 (094) 549-7455  |
# |       2       |   7371    | Hartana      | Mulyani     | +62 (87) 409 9230   |
# |       3       |   3471    | Gatra        | Kusumo      | (065) 389-3069      |
# |       4       |   3578    | Gilda        | Gunarto     | +62 (088) 622-5461  |
# |       5       |   6471    | Muni         | Pradipta    | +62 (412) 709 4014  |
# |       6       |   3175    | Wirda        | Padmasari   | (0116) 065-9692     |
# |       7       |   3172    | Adinata      | Kuswoyo     | +62 (096) 282-3579  |
# |       8       |   3273    | Slamet       | Wibowo      | +62 (56) 762 4178   |
# |       9       |   3174    | Febi         | Sinaga      | +62 (394) 988 2654  |
# |      10       |   3273    | Daliman      | Permata     | +62 (19) 318-8088   |
# |      11       |   3175    | Ciaobella    | Samosir     | +62 (59) 073 7504   |
# |      12       |   3471    | Hari         | Suwarno     | +62 (072) 884-3295  |
# |      13       |   6471    | Jarwadi      | Utama       | +62-826-638-7392    |
# |      14       |   6471    | Praba        | Kurniawan   | +62 (60) 150 3826   |
# |      15       |   3175    | Respati      | Sudiati     | (0292) 140 5565     |
# |      16       |   6471    | Garda        | Haryanto    | +62 (29) 552 8452   |
# |      17       |   3175    | Oman         | Rahimah     | +62 (41) 519 0048   |
# |      18       |   7371    | Maryanto     | Widiastuti  | (0128) 180 1004     |
# |      19       |   5171    | Widya        | Hardiansyah | (082) 115 9769      |
# |      20       |   3171    | Cayadi       | Siregar     | +62 (83) 806 9830   |
# |      21       |   1375    | Prakosa      | Maryadi     | +62 (78) 573 7724   |
# |      22       |   3172    | Jumari       | Wibowo      | +62 (0667) 406-9816 |
# |      23       |   3171    | Salwa        | Pudjiastuti | (0855) 789-4830     |
# |      24       |   3573    | Jagaraga     | Putra       | +62-0732-172-3264   |
# |      25       |   3173    | Ibrani       | Simbolon    | 085 669 4230        |
# |      26       |   3171    | Galur        | Prastuti    | (0243) 148 6175     |
# |      27       |   3174    | Bakijan      | Agustina    | (092) 406-2642      |
# |      28       |   6471    | Shakila      | Situmorang  | 0854771223          |
# |      29       |   3175    | Daniswara    | Agustina    | +62 (400) 055-3950  |
# |      30       |   6472    | Ira          | Tamba       | 0847944202          |
# |      31       |   3171    | Karna        | Nasyidah    | +62 (052) 393-3297  |
# |      32       |   3171    | Erik         | Wasita      | +62 (0841) 811-9947 |
# |      33       |   3578    | Omar         | Tarihoran   | (0040) 808-3178     |
# |      76       |   3173    | Tari         | Jailani     | +62-013-281-1820    |
# |      77       |   1371    | Mala         | Usamah      | +62 (0526) 179-8500 |
# |      78       |   3174    | Prabu        | Wijayanti   | +62 (078) 660 1763  |
# |      79       |   3471    | Maras        | Uyainah     | +62-0200-424-1741   |
# |      80       |   5171    | Cornelia     | Waluyo      | +62-0909-248-2527   |
# |      81       |   3171    | Edison       | Handayani   | +62 (011) 196-5163  |
# |      82       |   3573    | Abyasa       | Ramadan     | (043) 222-6567      |
# |      83       |   3174    | Waluyo       | Ardianto    | +62-276-703-7572    |
# |      84       |   6471    | Ihsan        | Wibowo      | +62 (009) 897-0684  |
# |      85       |   3471    | Wardi        | Prabowo     | (007) 058-0445      |
# |      86       |   3273    | Bahuwarna    | Manullang   | +62-57-316-1202     |
# |      87       |   3273    | Uda          | Nasyiah     | +62-025-921-9853    |
# |      88       |   1375    | Rusman       | Astuti      | +62 (003) 548 3924  |
# |      89       |   3273    | Arta         | Jailani     | +62-0974-192-6612   |
# |      90       |   3573    | Tira         | Nababan     | +62 (067) 609 3906  |
# |      91       |   3578    | Legawa       | Napitupulu  | +62 (446) 655 2654  |
# |      92       |   3573    | Latika       | Pratama     | 0868232664          |
# |      93       |   1375    | Laila        | Setiawan    | (0520) 943 1903     |
# |      94       |   3175    | Utama        | Puspasari   | +62-020-291-0916    |
# |      95       |   1371    | Cahya        | Jailani     | +62 (015) 159-8031  |
# |      96       |   1371    | Gatot        | Wijaya      | +62-31-465-5755     |
# |      97       |   3171    | Jinawi       | Manullang   | +62 (019) 762 4115  |
# |      98       |   3273    | Ibrani       | Narpati     | (0695) 024 0964     |
# |      99       |   3573    | Luis         | Budiyanto   | +62 (20) 096-1617   |
# |      100      |   3573    | Oskar        | Permadi     | +62 (191) 245-8502  |
# +---------------+-----------+--------------+-------------+---------------------+

# %% [markdown]
# ### Dummy data tabel ads
# * Deskripsi: Menyimpan informasi tentang iklan
# * Relasi: Tabel sellers dan products(Parent Table)

# %%
# Ekstrak file car_product.csv menjadi list of dictionary
product_table = csv_to_dict('car_product.csv')

# %%
# Lihat data cities
show_data(product_table)
# Out:
# +--------------+----------+-----------------+-------------+--------+-----------+
# |  product_id  | brand    | model           | body_type   |  year  |   price   |
# |--------------+----------+-----------------+-------------+--------+-----------|
# |      1       | Toyota   | Toyota Yaris    | Hatchback   |  2016  | 175000000 |
# |      2       | Toyota   | Toyota Yaris    | Hatchback   |  2018  | 215000000 |
# |      3       | Toyota   | Toyota Yaris    | Hatchback   |  2014  | 162000000 |
# |      4       | Toyota   | Toyota Yaris    | Hatchback   |  2020  | 220000000 |
# |      5       | Toyota   | Toyota Yaris    | Hatchback   |  2012  | 124000000 |
# |      6       | Toyota   | Toyota Agya     | Hatchback   |  2019  | 114000000 |
# |      7       | Toyota   | Toyota Agya     | Hatchback   |  2014  | 97000000  |
# |      8       | Toyota   | Toyota Agya     | Hatchback   |  2016  | 110000000 |
# |      9       | Toyota   | Toyota Agya     | Hatchback   |  2022  | 155500000 |
# |      49      | Suzuki   | Suzuki Ertiga   | MPV         |  2012  | 100000000 |
# |      50      | Suzuki   | Suzuki Ertiga   | MPV         |  2018  | 167000000 |
# +--------------+----------+-----------------+-------------+--------+-----------+

# %%
def generate_ads_title(n_data, product_table):
    """
    Fungsi untuk membuat ads title dummy

    arg:
        - n_data (int) : jumlah data yang ingin dibuat
        - product_table (list) : list of dictionary data product

    return:
        titles (list) : list title yang sudah dibuat
    """
    
    titles = list()
    verbs = ("Dijual", "Termurah", "Dijual cepat", "Dijamin termurah", "Pasti murah")
    
    while len(titles) < n_data:
        brand = random.choice(product_table["brand"])
        body_type = random.choice(product_table["body_type"])
        verb = random.choice(verbs)
        
        title = f'{verb} {brand} {body_type}'
        titles.append(title)
    
    return titles

# %%
def ad_table(n_data, seller_table, product_table, is_print):
    """
    Fungsi untuk membuat dummy data ad table
    header:
        - ad_id
        - seller_id
        - product_id
        - title 
        - description
        - date_post
        - is_bid
    arg:
        - n_data (int)  : Jumlah data yang ingin dibuat
        - seller_table (list)  : list of dictionary data seller
        - product_table (list)  : list of dictionary data product
        - is_print  (bool) : Jika True akan menampilkan hasil data

    return:
        - table  (list) :  
    """
    # definisikan awal tanggal
    start_date = datetime(2022, 1, 1)

    # definisikan akhir tanggal
    end_date = datetime(2022, 6, 1)
    
    # Buat table
    table = {}
    table["ad_id"] = [i+1 for i in range(n_data)]
    table["seller_id"] = [random.choice(seller_table['seller_id']) for i in range(n_data)]
    table["product_id"] = [random.choice(product_table['product_id']) for i in range(n_data)]
    titles = generate_ads_title(n_data, product_table)
    table["title"] = [i for i in titles]
    table["description"] = [FAKER.text() for i in range(n_data)]
    table["date_post"] = [FAKER.date_between(start_date=start_date, end_date=end_date) for i in range(n_data)]
    table["is_bid"] = [FAKER.pybool() for i in range(n_data)]

    # Print table
    if is_print:
        show_data(table)

    return table

# %%
ad_table = ad_table(n_data=100, seller_table=seller_table, product_table=product_table, is_print=True)
# Out:
# +---------+-------------+--------------+-------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+----------+
# |  ad_id  |  seller_id  |  product_id  | title                               | description                                                                                                                                                                                     | date_post   | is_bid   |
# |---------+-------------+--------------+-------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+----------|
# |    1    |     37      |      17      | Dijual cepat Daihatsu Wagon         | Enim voluptates quas aliquam explicabo eius laboriosam eos. Cupiditate tempore perspiciatis sint doloribus deserunt deleniti.                                                                   | 2022-01-21  | True     |
# |         |             |              |                                     | Iure minima repellat repudiandae.                                                                                                                                                               |             |          |
# |    2    |     65      |      27      | Dijual cepat Daihatsu Wagon         | Vel minima quod quia minima quo. Occaecati magni mollitia doloremque nesciunt modi illo. Nisi facere labore quibusdam est.                                                                      | 2022-02-24  | False    |
# |         |             |              |                                     | Qui sequi ullam totam architecto placeat. Error quidem vitae enim.                                                                                                                              |             |          |
# |    3    |     99      |      32      | Dijual cepat Toyota SUV             | Eum a officiis veniam. Velit aut corporis vel tenetur illum enim id. Mollitia exercitationem reiciendis eveniet odio. Nulla quia aspernatur porro aspernatur.                                   | 2022-02-21  | True     |
# |         |             |              |                                     | Porro error eius possimus quis.                                                                                                                                                                 |             |          |
# |         |             |              |                                     | Illum quis id. Tempore nam animi doloremque incidunt.                                                                                                                                           |             |          |
# |   17    |      5      |      15      | Termurah Daihatsu MPV               | Reprehenderit adipisci excepturi quae. Eos ipsa non laudantium reprehenderit consequatur commodi tempora. Consequatur reiciendis praesentium magni sapiente.                                    | 2022-02-17  | True     |
# |   18    |     69      |      27      | Dijual Toyota MPV                   | Vero sed corporis maxime sint praesentium. Laudantium hic recusandae laudantium nobis dolor labore.                                                                                             | 2022-05-08  | True     |
# |   19    |     70      |      12      | Termurah Honda Hatchback            | Aspernatur asperiores molestiae. Adipisci necessitatibus distinctio et. A expedita nisi ducimus vitae velit doloribus.                                                                          | 2022-04-16  | True     |
# |   20    |     50      |      33      | Pasti murah Toyota Hatchback        | Totam natus quos. Dignissimos enim doloremque reiciendis quidem occaecati excepturi. Modi magni aperiam ad exercitationem nulla officiis.                                                       | 2022-02-01  | False    |
# |   21    |     75      |      36      | Dijual Honda Hatchback              | Consequatur vitae sint eligendi. Repudiandae illum provident rerum. Quas laborum commodi eum. Nulla minima impedit dolore.                                                                      | 2022-05-07  | False    |
# |         |             |              |                                     | Laudantium iste incidunt ipsam.                                                                                                                                                                 |             |          |
# |   22    |     11      |      38      | Pasti murah Toyota Wagon            | Magnam quisquam pariatur ipsa qui non deserunt. Quisquam voluptates deleniti. Sint assumenda officia distinctio voluptatum blanditiis dolor.                                                    | 2022-05-06  | True     |
# |   23    |     11      |      23      | Dijual Daihatsu Hatchback           | Laborum porro nobis adipisci. Excepturi tempore cumque similique.                                                                                                                               | 2022-01-15  | True     |
# |         |             |              |                                     | Sit quibusdam laborum aperiam quis voluptate illum. Rem dolores eius qui minima soluta.                                                                                                         |             |          |
# |   24    |      6      |      49      | Dijual cepat Daihatsu MPV           | Voluptatibus laborum placeat. Commodi nisi quaerat esse saepe. Voluptatibus officia perspiciatis tenetur incidunt.                                                                              | 2022-03-15  | True     |
# |         |             |              |                                     | Unde ipsam atque sapiente distinctio explicabo. Rerum modi porro inventore.                                                                                                                     |             |          |
# |   25    |     41      |      1       | Dijual Toyota Hatchback             | Architecto possimus dolor eligendi nisi. Alias deserunt fugit ad perferendis incidunt architecto.                                                                                               | 2022-05-21  | False    |
# |         |             |              |                                     | Quae sunt facilis debitis quidem. Molestiae molestias et.                                                                                                                                       |             |          |
# |   26    |     75      |      39      | Termurah Honda Hatchback            | Voluptate quibusdam nulla. Blanditiis veritatis maiores rerum odio mollitia porro.                                                                                                              | 2022-04-01  | False    |
# |         |             |              |                                     | Maiores recusandae voluptatibus ad ab fugiat.                                                                                                                                                   |             |          |
# |   27    |     95      |      29      | Pasti murah Daihatsu Hatchback      | Mollitia quaerat debitis voluptas exercitationem. Nulla optio earum molestiae ab. At quae odio eos.                                                                                             | 2022-02-14  | True     |
# |   28    |     38      |      27      | Dijual Daihatsu SUV                 | Sit corrupti temporibus esse dolorum. Architecto illum modi laudantium odio iure.                                                                                                               | 2022-02-11  | False    |
# |   91    |     61      |      1       | Pasti murah Daihatsu SUV            | Facere incidunt possimus nulla architecto. Culpa accusantium accusamus aliquid cupiditate officia.                                                                                              | 2022-04-05  | False    |
# |   92    |     69      |      25      | Pasti murah Honda Hatchback         | Sapiente dolore cum sit odio. Quasi veritatis tempore quod quibusdam. Architecto ipsam natus eius inventore quam.                                                                               | 2022-03-25  | False    |
# |   93    |     100     |      27      | Termurah Toyota SUV                 | Possimus quisquam fugiat iure blanditiis. Expedita quaerat ad cumque.                                                                                                                           | 2022-04-25  | True     |
# |   94    |     23      |      10      | Pasti murah Toyota Hatchback        | Eius laborum quae perferendis vel autem vero. Amet asperiores fuga sint excepturi. Totam rerum facilis deserunt.                                                                                | 2022-03-28  | True     |
# |   95    |     19      |      30      | Dijual cepat Toyota Hatchback       | Labore doloremque maiores blanditiis magni. Qui amet eum laboriosam consequatur ducimus. Officiis voluptatibus facilis labore natus.                                                            | 2022-04-10  | False    |
# |   96    |     91      |      40      | Termurah Honda Hatchback            | Corrupti libero aspernatur corrupti assumenda dolorem itaque adipisci. Ea ab repellat non repellat at temporibus.                                                                               | 2022-01-21  | True     |
# |   97    |     76      |      34      | Pasti murah Suzuki MPV              | Laborum sint aut reprehenderit. Ipsum earum expedita incidunt veniam. Ad facilis fugiat quod mollitia nobis harum.                                                                              | 2022-02-19  | False    |
# |   98    |     76      |      3       | Termurah Daihatsu MPV               | Adipisci sint voluptatum blanditiis. Ullam at aspernatur nostrum incidunt.                                                                                                                      | 2022-05-09  | False    |
# |         |             |              |                                     | Saepe deleniti eos distinctio. Non praesentium dicta praesentium doloribus illum asperiores ex.                                                                                                 |             |          |
# |   99    |     93      |      14      | Pasti murah Toyota Hatchback        | Facilis sequi nulla itaque quidem in a. Tempore architecto incidunt reprehenderit nostrum nisi. Aperiam aliquid excepturi aliquam.                                                              | 2022-03-03  | True     |
# |         |             |              |                                     | Natus alias provident. Dolorum veniam illo deserunt eos saepe.                                                                                                                                  |             |          |
# |   100   |     37      |      26      | Dijual cepat Daihatsu MPV           | Excepturi repellat consequuntur ducimus quae. Eaque enim culpa laborum. Temporibus nihil corporis perspiciatis sed incidunt amet. Error maxime architecto id officiis enim sunt.                | 2022-03-12  | False    |
# +---------+-------------+--------------+-------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+----------+

# %% [markdown]
# ### Dummy data tabel bids
# * Deskripsi: Menyimpan informasi tentang penawaran yang dilakukan customer
# * Relasi: Tabel customers dan ads(Parent Table)

# %%
def bid_table(n_data, ad_table, customer_table, is_print):
    """
    Fungsi untuk membuat dummy data bid table
    header:
        - bid_id
        - ad_id
        - customer_id
        - date_bid
        - price_bid
        - status_bid
    arg:
        - n_data (int)  : Jumlah data yang ingin dibuat
        - ad_table (list)  : list of dictionary data ad
        - customer_id (list)  : list of dictionary data customer
        - is_print  (bool) : Jika True akan menampilkan hasil data

    return:
        - table  (list) :  
    """
    # definisikan awal tanggal
    start_date = datetime(2022, 6, 2)

    # definisikan akhir tanggal
    end_date = datetime(2022, 12, 31)
    
    # list penawaran harga
    
    # list status bid
    status_bid = ["Sent", "Cancelled"]
    
    # Buat table
    table = {}
    table["bid_id"] = [i+1 for i in range(n_data)]
    table["ad_id"] = [random.choice(ad_table['ad_id']) for i in range(n_data)]
    table["customer_id"] = [random.choice(customer_table['customer_id']) for i in range(n_data)]
    table["date_bid"] = [FAKER.date_between(start_date=start_date, end_date=end_date) for i in range(n_data)]
    table["price_bid"] = [FAKER.random_int(100_000_000,500_000_000, 25_000_000) for i in range(n_data)]
    table["status_bid"] = [random.choice(status_bid) for i in range(n_data)]
    # Print table
    if is_print:
        show_data(table)

    return table

# %%
bid_table = bid_table(n_data=100, ad_table=ad_table, customer_table=customer_table, is_print=True)
# Out:
# +----------+---------+---------------+------------+-------------+--------------+
# |  bid_id  |  ad_id  |  customer_id  | date_bid   |  price_bid  | status_bid   |
# |----------+---------+---------------+------------+-------------+--------------|
# |    1     |   43    |      75       | 2022-09-14 |  375000000  | Cancelled    |
# |    2     |   58    |      22       | 2022-08-16 |  200000000  | Sent         |
# |    3     |   16    |      83       | 2022-09-04 |  150000000  | Cancelled    |
# |    4     |   26    |      89       | 2022-10-03 |  325000000  | Sent         |
# |    5     |   83    |      23       | 2022-10-26 |  500000000  | Sent         |
# |    6     |   38    |      18       | 2022-07-18 |  400000000  | Sent         |
# |    7     |   94    |      49       | 2022-06-28 |  200000000  | Sent         |
# |    8     |   16    |      36       | 2022-07-26 |  100000000  | Sent         |
# |    9     |   96    |      30       | 2022-08-17 |  425000000  | Sent         |
# |    10    |   18    |       4       | 2022-07-22 |  400000000  | Cancelled    |
# |    11    |   49    |      84       | 2022-09-23 |  425000000  | Sent         |
# |    12    |   44    |      44       | 2022-09-26 |  125000000  | Cancelled    |
# |    13    |   30    |      89       | 2022-11-18 |  150000000  | Sent         |
# |    14    |   71    |      93       | 2022-06-29 |  375000000  | Cancelled    |
# |    15    |   51    |      18       | 2022-09-24 |  300000000  | Cancelled    |
# |    16    |   44    |      94       | 2022-11-03 |  225000000  | Sent         |
# |    17    |   38    |      88       | 2022-11-20 |  325000000  | Sent         |
# |    18    |    2    |      30       | 2022-12-03 |  400000000  | Sent         |
# |    19    |   92    |      49       | 2022-12-08 |  225000000  | Cancelled    |
# |    20    |   68    |      72       | 2022-09-02 |  475000000  | Sent         |
# |    21    |   87    |      31       | 2022-06-16 |  325000000  | Sent         |
# |    22    |    3    |       2       | 2022-11-18 |  350000000  | Sent         |
# |    23    |    5    |      69       | 2022-08-06 |  325000000  | Cancelled    |
# |    24    |   77    |      82       | 2022-12-22 |  100000000  | Cancelled    |
# |    25    |   28    |      55       | 2022-11-07 |  475000000  | Sent         |
# |    26    |   50    |      75       | 2022-10-23 |  475000000  | Cancelled    |
# |    27    |   31    |      52       | 2022-08-24 |  375000000  | Cancelled    |
# |    28    |   82    |      85       | 2022-10-03 |  200000000  | Cancelled    |
# |    29    |   59    |      19       | 2022-07-17 |  300000000  | Cancelled    |
# |    30    |   10    |      24       | 2022-06-28 |  300000000  | Cancelled    |
# |    74    |   79    |      13       | 2022-06-13 |  225000000  | Sent         |
# |    75    |   25    |      81       | 2022-06-23 |  275000000  | Cancelled    |
# |    76    |    7    |      87       | 2022-06-26 |  350000000  | Sent         |
# |    77    |   86    |      55       | 2022-08-03 |  325000000  | Cancelled    |
# |    78    |   16    |      42       | 2022-10-24 |  325000000  | Sent         |
# |    79    |   54    |      83       | 2022-08-23 |  325000000  | Sent         |
# |    80    |   23    |      87       | 2022-09-27 |  200000000  | Sent         |
# |    81    |   91    |      70       | 2022-06-29 |  250000000  | Cancelled    |
# |    82    |   13    |      41       | 2022-11-01 |  100000000  | Cancelled    |
# |    83    |   34    |      39       | 2022-08-01 |  500000000  | Cancelled    |
# |    84    |   89    |      79       | 2022-06-11 |  100000000  | Sent         |
# |    85    |   44    |      57       | 2022-12-14 |  475000000  | Cancelled    |
# |    86    |   39    |      26       | 2022-07-29 |  250000000  | Sent         |
# |    87    |   92    |      32       | 2022-10-27 |  325000000  | Sent         |
# |    88    |   21    |      41       | 2022-09-06 |  475000000  | Cancelled    |
# |    89    |   17    |       1       | 2022-10-14 |  425000000  | Sent         |
# |    90    |   57    |      79       | 2022-12-02 |  175000000  | Cancelled    |
# |    91    |    8    |      93       | 2022-08-08 |  275000000  | Sent         |
# |    92    |   48    |      26       | 2022-06-27 |  350000000  | Cancelled    |
# |    93    |   35    |      37       | 2022-10-31 |  225000000  | Sent         |
# |    94    |   87    |      80       | 2022-06-18 |  325000000  | Cancelled    |
# |    95    |   20    |      53       | 2022-06-14 |  175000000  | Sent         |
# |    96    |    3    |      28       | 2022-12-12 |  275000000  | Cancelled    |
# |    97    |   49    |       8       | 2022-10-12 |  350000000  | Cancelled    |
# |    98    |    4    |      73       | 2022-11-09 |  275000000  | Sent         |
# |    99    |   71    |      81       | 2022-10-22 |  325000000  | Sent         |
# |   100    |   64    |      62       | 2022-12-10 |  275000000  | Sent         |
# +----------+---------+---------------+------------+-------------+--------------+

# %% [markdown]
# ## Simpan menjadi file csv

# %%
def save_to_csv(data, nama_file):
    '''
    Fungsi untuk menyimpan data dummy ke csv

    args:
        - data (list)     : list of dictionary data yang akan dijadikan csv
        - nama_file (str) : nama untuk file csv
	
	return:
		- None
    '''
   
    # Membuat file csv
    with open(file = f"{nama_file}.csv", mode = 'w', newline = '') as csv_file:
        # Membuat writer csv
        writer = csv.writer(csv_file)

        # write header csv
        writer.writerow(list(data.keys()))
        
        # mengetahui panjang data
        len_data = len(list(data.items())[0][1])
        
        # write data ke file csv
        for i in range(len_data):
            row = []
            for key in data.keys():
                row.append(data[key][i])
            writer.writerow(row)

# %%
# menyimpan data seller dalam bentuk csv
save_to_csv(data = seller_table,
            nama_file = 'seller_table')

# %%
# menyimpan data customer dalam bentuk csv
save_to_csv(data = customer_table,
            nama_file = 'customer_table')

# %%
# menyimpan data ads dalam bentuk csv
save_to_csv(data = ad_table,
            nama_file = 'ad_table')

# %%
# menyimpan data bid dalam bentuk csv
save_to_csv(data = bid_table,
            nama_file = 'bid_table')
